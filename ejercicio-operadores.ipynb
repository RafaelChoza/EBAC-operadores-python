# %%
def suma (numFloat1, numFloat2, numFloat3, numFloat4, numFloat5):
    return numFloat1 + numFloat2 + numFloat3 + numFloat4 + numFloat5

def resta (numFloat1, numFloat2, numFloat3, numFloat4, numFloat5):
    return numFloat1 - numFloat2 - numFloat3 - numFloat4 - numFloat5

def multiplicacion (numFloat1, numFloat2, numFloat3, numFloat4, numFloat5):
    return numFloat1 * numFloat2 * numFloat3 * numFloat4 * numFloat5

def division (numFloat1, numFloat2, numFloat3, numFloat4, numFloat5):
    return numFloat1 / numFloat2 / numFloat3 / numFloat4 / numFloat5

def potencia (numFloat1, numFloat2, numFloat3, numFloat4, numFloat5):
    return numFloat1 ** numFloat2 ** numFloat3 ** numFloat4 ** numFloat5


operation = int(input("""
                Ingrese el número de la operacion que desea hacer:
                0 --> Suma
                1 --> Resta
                2 --> Multiplicacion
                3 --> Division
                4 --> Potencia"""))


operationNumber = operation < 0 or operation > 5
operationInt = int(operationNumber)

operationMsg = ["","OPERACION NO VALIDA"]
print(operationMsg[operationInt])

## Se solicita al usurio ingresar 5 numeros que formarán la tupla

tuple = input("Ingresa una lista de 5 numeros separados por un espacio: ")

## Se dividen los 5 numeros ingresados en cada elemento de la tupla

splitTuple = tuple.split()

## Se asignan variables a cada elemento de la tupla

num1 = splitTuple[0]
num2 = splitTuple[1]
num3 = splitTuple[2]
num4 = splitTuple[3]
num5 = splitTuple[4]


## Se evalua si los elementos de la tupla son Float

isFloat1 = num1.count (".")
boolnum1 = bool(isFloat1)
isNumeric1 = num1.isdigit()
isStr1 = isFloat1 == 0 and isNumeric1 == 0
isNumericFLoat1 = isFloat1 == 1 and isNumeric1 == 1 and isStr1 == 0

isFloat2 = num2.count (".")
boolnum2 = bool(isFloat1)
isNumeric2 = num2.isdigit()
isStr2 = isFloat2 == 0 and isNumeric2 == 0
isNumericFLoat2 = isFloat2 == 1 and isNumeric2 == 1 and isStr2 == 1

isFloat3 = num3.count (".")
boolnum3 = bool(isFloat1)
isNumeric3 = num3.isdigit()
isStr3 = isFloat3 == 0 and isNumeric3 == 0
isNumericFLoat3 = isFloat3 == 1 and isNumeric3 == 1 and isStr3 == 1

isFloat4 = num4.count (".")
boolnum4 = bool(isFloat4)
isNumeric4 = num4.isdigit()
isStr4 = isFloat4 == 0 and isNumeric4 == 0
isNumericFLoat4 = isFloat4 == 1 and isNumeric4 == 1 and isStr4 == 1

isFloat5 = num5.count (".")
boolnum5 = bool(isFloat5)
isNumeric5 = num5.isdigit()
isStr5 = isFloat5 == 0 and isNumeric5 == 0
isNumericFLoat5 = isFloat5 == 1 and isNumeric5 == 1 and isStr5 == 1

strEval = int(isStr1 == 1 or isStr2 == 1 or isStr3 == 1 or isStr4 == 1 or isStr5 == 1)

strMsg = ["","Un dato ingresado no es Número, INGRESE SOLO NÚMEROS"]
print(strMsg[strEval])


## Se evalua si los elementos de la tupla son numeros complejos

isComplexNum1 = int(bool(num1.count("j")))
isComplexNum2 = int(bool(num2.count("j")))
isComplexNum3 = int(bool(num3.count("j")))
isComplexNum4 = int(bool(num4.count("j")))
isComplexNum5 = int(bool(num5.count("j")))

valNumber = isNumericFLoat1 == 1 or isNumericFLoat2 == 1 or isNumericFLoat3 == 1 or isNumericFLoat4 == 1 or isNumericFLoat5 == 1 
valComplex = isComplexNum1 == 1 or isComplexNum2 == 1 or isComplexNum3 == 1 or isComplexNum4 ==1 or isComplexNum5 == 1
valNumeric = int(isNumericFLoat1) == 1 or int(isNumericFLoat2) == 1 or int(isNumericFLoat3) == 1 or int(isNumericFLoat4) == 1 or int(isNumericFLoat5) == 1

messageResult = int(valNumber == 0 or valComplex == 0 or valNumeric == 0)
message = ["Un dato ingresado NO ES VALIDO", ""]

print(message[messageResult])

numFloat1 = float(num1)
numFloat2 = float(num2)
numFloat3 = float(num3)
numFloat4 = float(num4)
numFloat5 = float(num5)


tupleOperations = ("suma", "resta", "multiplicación", "division", "potencia")
arrayOperations = [suma, resta, multiplicacion, division, potencia]

print("La operación elegida es: ", tupleOperations[operation])


print ("El primer número ingresado es: ", numFloat1)
print ("El segundo número ingresado es: ", numFloat2)
print ("El tercer número ingresado es: ", numFloat3)  
print ("El cuarto número ingresado es: ", numFloat4)
print ("El quinto número ingresado es: ", numFloat5)


result = arrayOperations[operation](numFloat1, numFloat2, numFloat3, numFloat4, numFloat5)


print ("El resultado de la", tupleOperations[operation], "entre los 5 numero es: ", result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 25
#      14     return numFloat1 ** numFloat2 ** numFloat3 ** numFloat4 ** numFloat5
#      17 operation = int(input("""
#      18                 Ingrese el número de la operacion que desea hacer:
#      19                 0 --> Suma
#    (...)
#      22                 3 --> Division
#      23                 4 --> Potencia"""))
# ---> 25 operationLength = len(operation)
#      26 print(operationLength)
#      27 opLenEval = int(operationLength > 1)
#
# TypeError: object of type 'int' has no len()
